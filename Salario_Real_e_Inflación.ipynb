# %% [markdown]
# <a href="https://colab.research.google.com/github/guillermopose/Salarios-Inflacion/blob/main/Salario_Real_e_Inflaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Evolución conjunta de Salario Real e Inflación. Uruguay (2004-2024)**
#
# Este proyecto busca explorar la evolución entre la tasa de inflación y el salario real en Uruguay (2004-2024)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Datos a utilizar:
#
#
# 1.   Elemento de la lista
# 2.   Elemento de la lista
